# %% [markdown]
# # [Flight][Centralized] 03. Training and Test

# %% [markdown]
# ## 01. Imports and Settings

# %%
# Imports
from libs.anomaly_clf import (
    Autoencoder,
    OneClassSVMWrapper,
    LocalOutlierFactorWrapper,
    IsolationForestWrapper
)  # anomaly_clf.py
from libs.model_evaluation import test_model  # model_evaluation.py
from libs.pre_process import scaler_data  # pre_process.py
from libs.plots import show_scatterplot  # plots.py
from libs.utils import (
    split_X_y,
    split_train_test,
    save_object,
    load_object
)  # utils.py

import pandas as pd
import warnings


# Ignore warnings
warnings.filterwarnings("ignore")

# Pandas settings
pd.options.display.float_format = "{:.2f}".format
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)
pd.set_option("display.max_colwidth", 150)  # Increase column width

# Default path
DATA_PATH = "data/"
BIN_PATH = "bin/"

# %% [markdown]
# ## 02. Load and Pre-Process Data

# %%
# Load Jamming and Spoofing flight data
jamming_flight_df = pd.read_csv(f"{DATA_PATH}jamming_flight_preprocessed.csv")
spoofing_flight_df = pd.read_csv(f"{DATA_PATH}spoofing_flight_preprocessed.csv")
# Convert date columns to Pandas Datetime
jamming_flight_df["DateTime"] = pd.to_datetime(jamming_flight_df["DateTime"])
spoofing_flight_df["DateTime"] = pd.to_datetime(spoofing_flight_df["DateTime"])

# Split train and test data
train_df, test_df = split_train_test(jamming_flight_df, target_column="is_target", test_size=0.20)
# Split into X and y
X_train, y_train = split_X_y(train_df, "is_target", ["DateTime"])
X_test, y_test = split_X_y(test_df, "is_target", ["DateTime"])
# Spoofing flight data
X_spoofing, y_spoofing = split_X_y(spoofing_flight_df, "is_target", ["DateTime"])

# %%
# Scale training data
X_train_norm, scaler = scaler_data(X_train)
# Save scale object...
save_object(scaler, f"{BIN_PATH}scaler_obj")

# Load scale object...
scaler = load_object(f"{BIN_PATH}scaler_obj")
# Scale test data
X_test_norm, _ = scaler_data(X_test, scaler)
# And Spoofing flight data
X_spoofing_norm, _ = scaler_data(X_spoofing, scaler)

# %% [markdown]
# ## 03. Training and Test

# %%
# Dictionary to save models and their metrics
models = dict()

# Initializing for each classifier
for clf in ["autoencoder", "oc_svm", "lof", "iforest"]:
    models[clf] = {"obj": object(), "metrics": {}}

# %% [markdown]
# ### 03.1. Autoencoder

# %%
# Instantiate autoencoder
models["autoencoder"]["obj"] = Autoencoder(X_train_norm, y_train)
# Generate autoencoder model
models["autoencoder"]["obj"].create_model()

# %%
# Model training...
_, _, _ = models["autoencoder"]["obj"].fit_model(verbose=1)
# Save autoencoder object...
save_object(models["autoencoder"]["obj"], f"{BIN_PATH}autoencoder_obj")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728174238.136080  221266 service.cc:146] XLA service 0x71d5c0010010 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728174238.136111  221266 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - loss: 0.1848
# I0000 00:00:1728174240.434331  221266 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - loss: 0.1841
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.1722
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 0.1425
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.0878
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 0.0468
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.0442
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 0.0400
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0359
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 0.0338
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0280
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 0.0298
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 0.0236
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 0.0210
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0179
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 0.0165
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 0.0155
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.0152
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.0153
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 0.0145
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0131
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 0.0140
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0136
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.0136
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0124
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.0121
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.0119
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.0114
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 0.0115
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 0.0097
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0094
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.0091
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0087
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0087
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0086
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 0.0089
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0083
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0081
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0080
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0077
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0081
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 0.0075
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0078
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 0.0071
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 0.0067
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 0.0072
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0072
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 0.0071
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0070
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 0.0070
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0068
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 0.0069
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.0069
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0069
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0070
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0067
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 0.0064
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0067
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.0065
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0064
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 0.0066
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 0.0065
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0059
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 0.0061
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0062
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0059
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 0.0059
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0059
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.0058
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0063
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 0.0058
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 0.0060
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.0058
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 0.0061
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0059
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0057
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.0055
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 0.0055
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0056
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0055
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 0.0056
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0054
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0055
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057
#
# Mean Validation Loss (Normal): 0.032402 | (Abnormal): 0.166695

# %% [markdown]
# #### Reconstrunction Error

# %%
_ = models["autoencoder"]["obj"].plot_reconstrunction_error(X_test_norm)

# %% [markdown]
# #### Evaluate Model

# %%
# Evaluating...
models["autoencoder"]["metrics"] = test_model(models["autoencoder"]["obj"], X_test_norm.values, y_test)
# Out:
# Model Test: {'Precision': '100.0', 'Recall': '83.06', 'F1': '90.75', 'ROC_AUC': '91.53', 'Log_Loss': '3.5698'}

# %% [markdown]
# #### Test on Spoofing Flight Data

# %%
# Reconstrunction error...
_ = models["autoencoder"]["obj"].plot_reconstrunction_error(X_spoofing_norm)

# %%
# Latitude and Longitude in Spoofing data
# Biggest reconstruction errors are coinciding with the instant of the threat
show_scatterplot(spoofing_flight_df, "DateTime", "GpsLocationChanged_latitude", category="is_target");
show_scatterplot(spoofing_flight_df, "DateTime", "GpsLocationChanged_longitude", category="is_target")

# %%
# Evaluating...
_ = test_model(models["autoencoder"]["obj"], X_spoofing_norm.values, y_spoofing)
# Out:
# Model Test: {'Precision': '20.34', 'Recall': '100.0', 'F1': '33.81', 'ROC_AUC': '82.87', 'Log_Loss': '11.3529'}

# %% [markdown]
# ### 03.2. One-Class SVM (OC-SVM)

# %%
# Fit OC-SVM
models["oc_svm"]["obj"] = OneClassSVMWrapper().fit(X_train_norm[y_train == 0].values)
# Save OC-SVM object...
save_object(models["oc_svm"]["obj"], f"{BIN_PATH}oc_svm_obj")

# %% [markdown]
# #### Evaluate Model

# %%
# Evaluating...
models["oc_svm"]["metrics"] = test_model(models["oc_svm"]["obj"], X_test_norm.values, y_test)
# Out:
# Model Test: {'Precision': '72.05', 'Recall': '100.0', 'F1': '83.75', 'ROC_AUC': '72.69', 'Log_Loss': '8.176'}

# %% [markdown]
# ### 03.3. Local Outlier Factor (LOF)

# %%
# Fit LOF
models["lof"]["obj"] = LocalOutlierFactorWrapper().fit(X_train_norm[y_train == 0].values)
# Save LOF object...
save_object(models["lof"]["obj"], f"{BIN_PATH}lof_obj")

# %% [markdown]
# #### Evaluate Model

# %%
# Evaluating...
models["lof"]["metrics"] = test_model(models["lof"]["obj"], X_test_norm.values, y_test)
# Out:
# Model Test: {'Precision': '89.71', 'Recall': '100.0', 'F1': '94.57', 'ROC_AUC': '91.92', 'Log_Loss': '2.4183'}

# %% [markdown]
# ### 03.4. Isolation Forest (iForest)

# %%
# Fit iForest
models["iforest"]["obj"] = IsolationForestWrapper().fit(X_train_norm[y_train == 0].values)
# Save iForest object...
save_object(models["iforest"]["obj"], f"{BIN_PATH}iforest_obj")

# %% [markdown]
# #### Evaluate Model

# %%
# Evaluating...
models["iforest"]["metrics"] = test_model(models["iforest"]["obj"], X_test_norm.values, y_test)
# Out:
# Model Test: {'Precision': '86.32', 'Recall': '100.0', 'F1': '92.66', 'ROC_AUC': '88.85', 'Log_Loss': '3.3395'}

# %% [markdown]
# ## 04. Model Comparative

# %%
# Compare models
results_df = pd.DataFrame([{**{'Modelo': key.upper()}, **value['metrics']} for key, value in models.items()])
# Results...
display(results_df)
# Out:
#         Modelo Precision Recall     F1 ROC_AUC Log_Loss
# 0  AUTOENCODER     100.0  83.06  90.75   91.53   3.5698
# 1       OC_SVM     72.05  100.0  83.75   72.69    8.176
# 2          LOF     89.71  100.0  94.57   91.92   2.4183
# 3      IFOREST     86.32  100.0  92.66   88.85   3.3395
