# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt

# %%
# F1-score on each aggregation method and round
df = pd.DataFrame(data={
    "FedXgbBagging": [0.9133463616225059, 0.9058193331968853, 0.9021920587702341, 0.8881562567207497, 0.8726327565170652, 0.8699082077884985, 0.8644230470906474, 0.8609543775466381, 0.8621424219007859, 0.8643045991596932]
})

# %%
# DataFrame plot
plt.rc("font", **{"size":12}) # Setting font size 
df.plot(style=["+-", "o-", ".--", "s:", "-."])
plt.xlabel("Round", labelpad=12, fontsize=14)
plt.ylabel("F1-Score", labelpad=12, fontsize=14)
# Out:
# Text(0, 0.5, 'F1-Score')

# %%
# F1-score average
df.mean()
# Out:
# FedXgbBagging    0.880388
# dtype: float64

# %%
# ROC AUC average
pd.DataFrame(data={
    "FedXgbBagging" :[0.9990500000000001, 0.9991000000000000, 0.9972000000000000, 0.9971499999999999, 0.9969499999999999, 0.9967499999999999, 0.9962500000000001, 0.9961499999999999, 0.9963000000000000, 0.9961000000000000]
}).mean()
# Out:
# FedXgbBagging    0.9971
# dtype: float64
